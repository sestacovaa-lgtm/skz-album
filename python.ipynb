# %% [markdown]
# <a href="https://colab.research.google.com/github/sestacovaa-lgtm/skz-album/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [2,4,6,8,10]
my_list.append(99)
your_list = [3,5,7,9]
my_list.extend(your_list)
my_list.sort()
my_list.remove(10)
element = my_list.pop(0)

# %%
first = 'name1'
second = "name2"
text = "programe"
slice_1 = text[0:5]
slice_2 = text[:3]
word = 'PYthon'
word.upper()
word.lower()
user = input()
number = int(user)
# Out:
# 5

# %%
my_number = int(input())
number_person = int(input())
if my_number >= 600:
  print("chislo bolshe")
elif my_number == 600:
  print("chislo ravno")
else:
    print("chislo menshe")
# Out:
# 4
# 5
# chislo menshe

# %%
balance = int(input())
if balance <= 10:
  print("ok")
else:
  print("nope")
# Out:
# 5
# ok

# %%
correct_login = "admin"
correct_password = "pass1234"
users = []
user_login =input('vvedite login: ')
user_password =input('vvedite parol: ')
if user_login == correct_login and user_password == correct_password:
  print('dostup esti')
  users.append(user_login)
else:
  print('net dostupa')
# Out:
# vvedite login: admin
# vvedite parol: pass1234
# dostup esti

# %%
num_1 = int(input('vvedite chislo1: '))
operation =input('vvedite operation(+,-,*,/): ')
num_2 = int(input('vvedite chislo2: '))
match operation:
  case '+':
    print(num_1 + num_2)
  case '-':
    print(num_1 - num_2)
  case '*':
    print(num_1 * num_2)
  case '/':
    print(num_1 / num_2)
  case _:
    print('nope')
# Out:
# vvedite chislo1: 3
# vvedite operation(+,-,*,/): -
# vvedite chislo2: 6
# -3

# %%
dishes ={('pizza',120),('pasta',60)}
drinks = {('cola',25),('tea',20)}
order = []
choice =input('vvedite bludo:')
